# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
path=r"C:\Users\LISHI\OneDrive\Documents\Datafile\Visadataset - Visadataset.csv"
pd.read_csv(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # this change is for github

# %%
a=2
b=3
c=a*b
c
# Out:
# 6

# %%
import pandas as pd
path=r"C:\Users\LISHI\OneDrive\Documents\Datafile\bank - bank.csv"
pd.read_csv(path, header=None)
# Out:
#        0              1        2          3        4        5        6     7   \
# 0     age            job  marital  education  default  balance  housing  loan
# 1      30     unemployed  married    primary       no     1787       no    no
# 2      33       services  married  secondary       no     4789      yes   yes
# 3      35     management   single   tertiary       no     1350      yes    no
# 4      30     management  married   tertiary       no     1476      yes   yes
# ...   ...            ...      ...        ...      ...      ...      ...   ...
# 4517   33       services  married  secondary       no     -333      yes    no
# 4518   57  self-employed  married   tertiary      yes    -3313      yes   yes
# 4519   57     technician  married  secondary       no      295       no    no
# 4520   28    blue-collar  married  secondary       no     1137       no    no
# 4521   44   entrepreneur   single   tertiary       no     1136      yes   yes
#
# ...

# %% [markdown]
# $craete$ $Data$ $frame$

# %%
name=['Ramesh','Suresh','Satish']
age=[30,35,40]
name,age
pd.DataFrame()#create dataframe
pd.DataFrame(zip(name,age))#provide data
# Out:
#         0   1
# 0  Ramesh  30
# 1  Suresh  35
# 2  Satish  40

# %%
#provide column name
data=zip(name,age)
pd.DataFrame(data,columns=['Name','Age'])
# Out:
#      Name  Age
# 0  Ramesh   30
# 1  Suresh   35
# 2  Satish   40

# %%
#second way
data=zip(name,age)
cols=['Name','Age']
pd.DataFrame(data,columns=cols)
# Out:
#      Name  Age
# 0  Ramesh   30
# 1  Suresh   35
# 2  Satish   40

# %%
#provide index
data=zip(name,age)
pd.DataFrame(data,columns=['Name','Age'],index=['A','B','C'])
# Out:
#      Name  Age
# A  Ramesh   30
# B  Suresh   35
# C  Satish   40

# %%
#second way
data=zip(name,age)
cols=['Name','Age']
ind=['A','B','C']
pd.DataFrame(data,columns=cols,index=ind)
# Out:
#      Name  Age
# A  Ramesh   30
# B  Suresh   35
# C  Satish   40

# %% [markdown]
# $new column$

# %%
#adding new column
name=['Ramesh','Suresh','Satish']
age=[30,35,40]
data=zip(name,age)
cols=['Name','Age']
ind=['A','B','C']
df=pd.DataFrame(data,columns=cols,index=ind)
city_name=['Hyd','Blr','Chennai']
df['City']=city_name
df
# Out:
#      Name  Age     City
# A  Ramesh   30      Hyd
# B  Suresh   35      Blr
# C  Satish   40  Chennai

# %%
#update the existing column$

# %%
df['Name']=['Lisi','Lipi','Liza']
df
# Out:
#    Name  Age     City
# A  Lisi   30      Hyd
# B  Lipi   35      Blr
# C  Liza   40  Chennai

# %%
df['Age']=['25','35']
df
# Out:
#    Name Age
# A  Lisi  25
# C  Liza  35

# %%
#drop the column
df.drop('City',#column name
        axis=1,#column
        inplace=True)#overwrite coumn
df
# Out:
#    Name  Age
# A  Lisi   30
# B  Lipi   35
# C  Liza   40

# %%
#drop the rows
df.drop('B',axis=0,inplace=True)
df
# Out:
#    Name  Age
# A  Lisi   30
# C  Liza   40

# %%
#save the DataFrame
df.to_csv("output.csv")

# %%
#read output.csv
pd.read_csv("output.csv")
# Out:
#   Unnamed: 0  Name  Age
# 0          A  Lisi   30
# 1          C  Liza   40

# %%
#To avoid the extra column in the output file we need to do index=False
df.to_csv("output.csv",index=False)
pd.read_csv("output.csv")
# Out:
#    Name  Age
# 0  Lisi   30
# 1  Liza   40

# %%
#create dataframe using dictonary
d1={'name':['Ramesh','suresh','satish'],'age':[30,35,40]}
pd.DataFrame(d1)
# Out:
#      name  age
# 0  Ramesh   30
# 1  suresh   35
# 2  satish   40

# %%
d1
